# %%
# Dependencies
import pandas as pd
import csv
from sqlalchemy import create_engine
import plotly.express as px

# %%
#importing datasets
recovered = pd.read_csv('Resources/time_series_19-covid-Recovered.csv')
deaths = pd.read_csv('Resources/time_series_19-covid-Deaths.csv')
confirmed = pd.read_csv('Resources/time_series_19-covid-Confirmed.csv')

# %%
recovered.head()
recovered = recovered.drop(columns=['Lat', 'Long'])
df_recovered = pd.melt(recovered, id_vars=["Province/State", "Country/Region"])
df_recovered = df_recovered.rename(columns={"value": "Recovered Count", "variable": "Date"})
df_recovered.head()
# Out:
#   Province/State  Country/Region     Date  Recovered Count
# 0          Anhui  Mainland China  1/22/20                0
# 1        Beijing  Mainland China  1/22/20                0
# 2      Chongqing  Mainland China  1/22/20                0
# 3         Fujian  Mainland China  1/22/20                0
# 4          Gansu  Mainland China  1/22/20                0

# %%
deaths.head()
deaths = deaths.drop(columns=['Lat', 'Long'])
df_deaths = pd.melt(deaths, id_vars=["Province/State", "Country/Region"])
df_deaths = df_deaths.rename(columns={"value": "Deaths Count", "variable": "Date"})
df_deaths.head()
# Out:
#   Province/State  Country/Region     Date  Deaths Count
# 0          Anhui  Mainland China  1/22/20             0
# 1        Beijing  Mainland China  1/22/20             0
# 2      Chongqing  Mainland China  1/22/20             0
# 3         Fujian  Mainland China  1/22/20             0
# 4          Gansu  Mainland China  1/22/20             0

# %%
confirmed.head()
confirmed = confirmed.drop(columns=['Lat', 'Long'])
df_confirmed = pd.melt(confirmed, id_vars=["Province/State", "Country/Region"])
df_confirmed = df_confirmed.rename(columns={"value": "Confirmed Count", "variable": "Date"})
df_confirmed.head()
# Out:
#   Province/State  Country/Region     Date  Confirmed Count
# 0          Anhui  Mainland China  1/22/20                1
# 1        Beijing  Mainland China  1/22/20               14
# 2      Chongqing  Mainland China  1/22/20                6
# 3         Fujian  Mainland China  1/22/20                1
# 4          Gansu  Mainland China  1/22/20                0

# %%
df_combined = df_recovered.merge(df_deaths, on=("Province/State", "Country/Region", "Date"))
df_combined
# Out:
#               Province/State  Country/Region     Date  Recovered Count  \
# 0                      Anhui  Mainland China  1/22/20                0
# 1                    Beijing  Mainland China  1/22/20                0
# 2                  Chongqing  Mainland China  1/22/20                0
# 3                     Fujian  Mainland China  1/22/20                0
# 4                      Gansu  Mainland China  1/22/20                0
# ...                      ...             ...      ...              ...
# 6337            Berkeley, CA              US   3/3/20                0
# 6338     Maricopa County, AZ              US   3/3/20                0
# 6339         Wake County, NC              US   3/3/20                0
# 6340  Westchester County, NY              US   3/3/20                0
# 6341                     NaN         Ukraine   3/3/20                0
#
#       Deaths Count
# 0                0
# 1                0
# 2                0
# 3                0
# ...

# %%
df_combined = df_combined.merge(df_confirmed, on=("Province/State", "Country/Region", "Date"))
df_combined
# Out:
#               Province/State  Country/Region     Date  Recovered Count  \
# 0                      Anhui  Mainland China  1/22/20                0
# 1                    Beijing  Mainland China  1/22/20                0
# 2                  Chongqing  Mainland China  1/22/20                0
# 3                     Fujian  Mainland China  1/22/20                0
# 4                      Gansu  Mainland China  1/22/20                0
# ...                      ...             ...      ...              ...
# 6337            Berkeley, CA              US   3/3/20                0
# 6338     Maricopa County, AZ              US   3/3/20                0
# 6339         Wake County, NC              US   3/3/20                0
# 6340  Westchester County, NY              US   3/3/20                0
# 6341                     NaN         Ukraine   3/3/20                0
#
#       Deaths Count  Confirmed Count
# 0                0                1
# 1                0               14
# ...

# %%
fig = px.pie(recovered, values = 'Confirmed Count',names='Country/Region', height=600)
fig.update_traces(textposition='inside', textinfo='percent+label')

fig.update_layout(
    title_x = 0.5,
    geo=dict(
        showframe = False,
        showcoastlines = False,
    ))

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-fbd19d2671d0> in <module>
# ----> 1 fig = px.pie(recovered, values = 'Confirmed',names='Country/Region', height=600)
#       2 fig.update_traces(textposition='inside', textinfo='percent+label')
#       3
#       4 fig.update_layout(
#       5     title_x = 0.5,
#
# /Applications/anaconda3/lib/python3.7/site-packages/plotly/express/_chart_types.py in pie(data_frame, names, values, color, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, opacity, hole)
#    1250         constructor=go.Pie,
#    1251         trace_patch=dict(showlegend=(names is not None), hole=hole),
# -> 1252         layout_patch=layout_patch,
#    1253     )
#    1254
#
# ...

# %%
rds_connection_string = "postgres:postgres@localhost:5432/corona_db"
engine = create_engine(f'postgresql://{rds_connection_string}')


df_combined.to_sql(name='corona_virus', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-cabf6da17167> in <module>
#       1 rds_connection_string = "postgres:postgres@localhost:5432/corona_db"
# ----> 2 engine = create_engine(f'postgresql://{rds_connection_string}')
#       3
#       4
#       5 df_combined.to_sql(name='corona_virus', con=engine, if_exists='append', index=False)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     433     strategy = kwargs.pop("strategy", default_strategy)
#     434     strategy = strategies.strategies[strategy]
# --> 435     return strategy.create(*args, **kwargs)
#     436
#     437
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ...

# %%
pip install psycopg2
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/84/d7/6a93c99b5ba4d4d22daa3928b983cec66df4536ca50b22ce5dcac65e4e71/psycopg2-2.8.4.tar.gz
#     ERROR: Complete output from command python setup.py egg_info:
#     ERROR: running egg_info
#     creating pip-egg-info/psycopg2.egg-info
#     writing pip-egg-info/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to pip-egg-info/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to pip-egg-info/psycopg2.egg-info/top_level.txt
#     writing manifest file 'pip-egg-info/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
# ...
